# %% [markdown]
# ### Solving using monte carlo method (HW problem)
#   This will generate a plot of 100 darts thrown at a board

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as rnd
nsim=1000 #number of simulations
#on each axis generate random number
x=rnd.random()
y=rnd.random()
dart_crd=np.zeros((nsim,2))
for isim in range(nsim): dart_crd[isim,:]=[rnd.random(),rnd.random()]

fig=plt.figure(figsize=(7,7))
ax=fig.add_subplot(1,1,1)
ax.scatter (dart_crd[:,0]
           ,dart_crd[:,1])

#draw circle
nangle=151#number of angles, go with higher number to render a smooth line. Go with 50-100
angles=np.linspace(0,np.pi/2,nangle)
circle=np.zeros((nangle,2)) #zeros of 
circle[:,0]=np.cos(angles) # use cos for y value
circle[:,1]=np.sin(angles) #use sin for x value
ax.plot(circle[:,0], #this draws the actual line
       circle[:,1],
       c='red')
#need to approx the area below circle next

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as rnd

nsim=1000 #number of simulations
#on each axis generate random number
x=rnd.random()
y=rnd.random()
dart_crd=np.zeros((nsim,2))
circDartCounter=0

for isim in range(nsim): 
    dart_crd[isim,:]=[rnd.random()#x-value
                      ,rnd.random()]
    distanceSquared=dart_crd[isim,0]**2 + dart_crd[isim]
    
fig=plt.figure(figsize=(7,7))
ax=fig.add_subplot(1,1,1)
ax.scatter (dart_crd[:,0]
           ,dart_crd[:,1])

#draw circle
nangle=151#number of angles, go with higher number to render a smooth line. Go with 50-100
angles=np.linspace(0,np.pi/2,nangle)
circle=np.zeros((nangle,2)) #zeros of 
circle[:,0]=np.cos(angles) # use cos for y value
circle[:,1]=np.sin(angles) #use sin for x value
ax.plot(circle[:,0], #this draws the actual line
       circle[:,1],
       c='red')
#need to approx the area below circle next
pi=4*circDartCounter/nsim
print('Approximate value: ',pi)
# Out:
# Approximate value:  0.0
